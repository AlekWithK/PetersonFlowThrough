# %% [markdown]
# ### Issues:
# 1. WQ data ends 12/2019, but FT data goes through 2023
# 2. No time data for the vast majority of dataset, only date data
# 3. Not all stations have data for every date
# 4. Depth measurements don't seem to match in places where samples temporally overlap

# %% [markdown]
# ## Imports

# %%
import os
import math

import pandas as pd
import geopandas as gpd
import numpy as np
import geopy.distance
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import plotly.express as px # type: ignore

from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn import svm

from datetime import date, timedelta
from tqdm.auto import tqdm

tqdm.pandas()

# %%
# Water quality table from TableauDataAlpha
df_wq = pd.read_csv('Data Prep/tbl_sfbay_20240710_CLEANED.csv').reset_index(drop=True)
df_wq = df_wq.dropna(subset='Calculated_Chlorophyll') # drops ~1% of the dataset missing calcchlor values
df_wq.datetime = pd.to_datetime(df_wq.datetime)
df_wq['timestamp'] = df_wq.datetime.astype('int64').div(10**9)
display(df_wq.head())

# Flowthrough data
df_ft = pd.read_parquet('Merges/PETERSON_FINAL.parquet').reset_index(drop=True).drop(columns='index')
df_ft.datetime = pd.to_datetime(df_ft.datetime)
df_ft['timestamp'] = df_ft.datetime.astype('int64').div(10**9)
df_ft['water_temp'] = df_ft['water_temp'].combine_first(df_ft['bow_temp'])
df_ft.rename(columns={'chlor': 'Discrete_Chlorophyll'}, inplace=True)
display(df_ft.head())
# Out:
#          Date      Time   datetime  station_id  depth  Discrete_Chlorophyll  \
# 0  1994-11-29  00:00:00 1994-11-29        36.0    1.0                   NaN
# 1  1994-11-29  00:00:00 1994-11-29        36.0    2.0                   2.9
# 2  1994-11-29  00:00:00 1994-11-29        36.0    3.0                   NaN
# 3  1994-11-29  00:00:00 1994-11-29        36.0    4.0                   NaN
# 4  1994-11-29  00:00:00 1994-11-29        36.0    5.0                   NaN
#
#    Calculated_Chlorophyll  Discrete_Oxygen  Calculated_Oxygen  Discrete_SPM  \
# 0                     2.9              NaN                8.2           NaN
# 1                     2.9              7.9                8.2          95.3
# 2                     2.9              NaN                8.2           NaN
# 3                     2.9              NaN                8.2           NaN
# 4                     2.9              NaN                8.2           NaN
#
#    Calculated_SPM  Extinction_Coefficient  salinity  water_temp    timestamp
# 0            96.0                     NaN     27.63       10.23  786067200.0
# 1            98.0                     NaN     27.65       10.25  786067200.0
# 2            98.0                     NaN     27.69       10.27  786067200.0
# 3            96.0                     NaN     27.73       10.29  786067200.0
# 4            95.0                     NaN     27.75       10.29  786067200.0
#              datetime       lat       lon  depth  photic_depth  wind_spd  \
# 0 1994-11-29 05:25:21  37.55778 -122.2006    9.5           NaN       2.8
# 1 1994-11-29 05:25:27  37.55806 -122.2006    9.9           NaN       2.7
# 2 1994-11-29 05:25:33  37.55861 -122.2006   10.1           NaN       2.9
# 3 1994-11-29 05:25:39  37.55889 -122.2006   10.3           NaN       2.6
# 4 1994-11-29 05:25:45  37.55944 -122.2006   10.6           NaN       2.7
#
#    wind_dir  water_temp  air_temp  bow_temp  ...          file  \
# 0     333.0      10.667      5.99    10.667  ...  11290520.001
# 1     341.0      10.677      5.66    10.677  ...  11290520.001
# 2     341.0      10.685      5.83    10.685  ...  11290520.001
# 3     339.0      10.689      5.73    10.689  ...  11290520.001
# 4     342.0      10.691      5.68    10.691  ...  11290520.001
#
#           datetime_out    new_lat     new_lon      dist_m    p_id  \
# 0  1994-11-29 05:25:21  37.559167 -122.199167  199.311480  1102.0
# 1  1994-11-29 05:25:27  37.559500 -122.199833  173.585801  1104.0
# 2  1994-11-29 05:25:33  37.559500 -122.199833  119.774825  1104.0
# 3  1994-11-29 05:25:39  37.559500 -122.199833   95.772003  1104.0
# 4  1994-11-29 05:25:45  37.559833 -122.200333   49.607724  1107.0
#
#   d_from_start d_from_station station_id    timestamp
# 0    17.913932     929.348040       30.0  786086721.0
# 1    17.990672     998.896984       30.0  786086727.0
# 2    17.990672     998.896984       30.0  786086733.0
# 3    17.990672     998.896984       30.0  786086739.0
# 4    18.058674    1055.890438       30.0  786086745.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Correlation Matrix

# %%
matrix = df_wq.corr(numeric_only=True)['Calculated_Chlorophyll']
print(matrix)
# Out:
# station_id               -0.028267
# depth                    -0.089831
# Discrete_Chlorophyll      0.988733
# Calculated_Chlorophyll    1.000000
# Discrete_Oxygen           0.270735
# Calculated_Oxygen         0.267630
# Discrete_SPM              0.192248
# Calculated_SPM            0.184638
# Extinction_Coefficient    0.215649
# salinity                  0.016713
# water_temp                0.002246
# timestamp                -0.101290
# Name: Calculated_Chlorophyll, dtype: float64

# %%
df_wq_plot = df_wq.dropna(subset=['Discrete_Chlorophyll', 'Calculated_Chlorophyll'])
#df_wq_plot = df_wq_plot[df_wq_plot.datetime.dt.year.between(2016, 2019)]

ax = df_wq_plot.plot('datetime', 'Discrete_Chlorophyll', kind='scatter', s=5, c='red')
df_wq_plot.plot(ax=ax, x='datetime', y='Calculated_Chlorophyll', kind='scatter', s=5, c='green')
# Out:
# <Axes: xlabel='datetime', ylabel='Calculated_Chlorophyll'>

# %% [markdown]
# ## Method: k-NN Model
# RSE = 0.45 @ k=2

# %%
df_wq.dropna(subset=['timestamp', 'station_id', 'Discrete_Chlorophyll', ], inplace=True)

X = df_wq[['timestamp', 'station_id', 'Discrete_Chlorophyll', ]]
y = df_wq['Calculated_Chlorophyll']

index = []
err = []
for i in range(1, 5):
    knn = KNeighborsRegressor(n_neighbors=i, n_jobs=8)
    knn.fit(X, y)
    y_pred = knn.predict(X)
    rss = sum((y_pred - y) ** 2)
    rse = math.sqrt(rss/(len(y)-2))
    index.append(i)
    err.append(rse)

print(err)
plt.plot(index, err)
plt.xlabel('Values of K')
plt.ylabel('RSE Error')
plt.title('Graph: K VS Error')
plt.show()
# Out:
# [0.14516094112084815, 1.3768984761213248, 1.924236751799231, 2.40135031605711]

# %%
knn = KNeighborsRegressor(n_neighbors=1, n_jobs=8)
knn.fit(X, y)
test = df_ft[df_ft.station_id == 36].head(10)
test = test.drop(columns=['lat', 'lon', 'photic_depth'])
display(test.head())

x_pred = knn.predict(test[['timestamp', 'station_id', 'Discrete_Chlorophyll']])
print(x_pred)
# Out:
#                datetime  depth  wind_spd  wind_dir  water_temp  air_temp  \
# 402 1994-11-29 06:06:50    8.8       8.9     117.0      10.267      5.74
# 403 1994-11-29 06:06:56    8.3       9.0     118.0      10.268      5.37
# 404 1994-11-29 06:07:02    7.9       8.7     114.0      10.269      5.58
# 405 1994-11-29 06:07:08    7.5       9.2     116.0      10.267      5.51
# 406 1994-11-29 06:07:14    7.7       8.7     115.0      10.268      5.38
#
#      bow_temp  barometer  Discrete_Chlorophyll  turbidity  ...          file  \
# 402    10.267     1025.4                   1.1   0.010109  ...  11290520.001
# 403    10.268     1025.4                   1.1   0.010175  ...  11290520.001
# 404    10.269     1025.4                   1.1   0.010183  ...  11290520.001
# 405    10.267     1025.7                   1.1   0.010225  ...  11290520.001
# 406    10.268     1025.7                   1.1   0.010307  ...  11290520.001
#
#             datetime_out    new_lat     new_lon      dist_m   p_id  \
# 402  1994-11-29 06:06:50  37.475333 -122.072667  251.097050  121.0
# 403  1994-11-29 06:06:56  37.475000 -122.072000  248.385354  118.0
# 404  1994-11-29 06:07:02  37.475000 -122.072000  256.222798  118.0
# 405  1994-11-29 06:07:08  37.474333 -122.070833  261.109352  112.0
# 406  1994-11-29 06:07:14  37.474333 -122.070833  238.406847  112.0
#
#     d_from_start d_from_station  station_id    timestamp
# 402     1.458347     680.558667        36.0  786089210.0
# 403     1.385144     611.196580        36.0  786089216.0
# 404     1.385144     611.196580        36.0  786089222.0
# 405     1.253479     484.277596        36.0  786089228.0
# 406     1.253479     484.277596        36.0  786089234.0
#
# [5 rows x 26 columns]
# [2.9 2.9 2.9 2.9 2.9 2.9 2.9 2.9 2.9 2.9]

# %% [markdown]
# ## Method: SVR

# %%
X = df_wq[['timestamp', 'station_id', 'depth', 'salinity', 'water_temp']]
y = df_wq['Calculated_Chlorophyll']

reg_svm = svm.SVR(cache_size=1000)
reg_svm.fit(X, y)

test = df_ft.head(50)
test = test.drop(columns=['lat', 'lon', 'photic_depth'])
display(test.head())

x_pred = reg_svm.predict(test[['timestamp', 'station_id', 'depth', 'salinity', 'water_temp']])
print(x_pred)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
